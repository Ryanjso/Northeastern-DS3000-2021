# %% [markdown]
# <center> <img src="https://yildirimcaglar.github.io/ds3000/ds3000.png"> </center>

# %% [markdown]
# <center> <h2> Data Wrangling Cont'd </h2></center>

# %% [markdown]
# ## Outline
# 1. <a href='#1'>Multilevel/Hierarchical Indexing</a>
# 2. <a href='#2'>Working with Missing Values in DataFrames</a>
# 3. <a href='#3'>Working with Duplicates</a>
# 4. <a href='#4'>Replacing Values</a>
# 5. <a href='#5'>Renaming Axis Indices</a>

# %% [markdown]
# <a id="1"></a>

# %% [markdown]
# ## 1. Multilevel/Hierarchical Indexing
# * Can index dataframes using two columns as indices
# * Use the **set_index** method and pass in a **list of column names**

# %%
import pandas as pd

# %%
#need to have saved the output from the previous Notebook as a csv file
df = pd.read_csv("res/ave_grades.csv")

# %%
df
# Out:
#               Student       House  Potion_Ave  Charm_Ave
# 0    Hermione Granger  Gryffindor       100.0      100.0
# 1   Anthony Goldstein   Ravenclaw        89.0       87.0
# 2        Harry Potter  Gryffindor        88.0       90.0
# 3         Lisa Turpin   Ravenclaw        86.5       84.0
# 4      Michael Corner   Ravenclaw        85.5       86.5
# 5        Draco Malfoy   Slytherin        84.5       81.0
# 6         Susan Bones  Hufflepuff        84.0       83.5
# 7         Ron Weasley  Gryffindor        83.0       87.5
# 8       Hannah Abbott  Hufflepuff        80.5       84.5
# 9     Ernie Macmillan  Hufflepuff        77.5       85.0
# 10      Gregory Goyle   Slytherin        66.5       59.5
# 11     Vincent Crabbe   Slytherin        64.0       60.0

# %%
df = df.set_index("Student")

# %%
df
# Out:
#                         House  Potion_Ave  Charm_Ave
# Student
# Hermione Granger   Gryffindor       100.0      100.0
# Anthony Goldstein   Ravenclaw        89.0       87.0
# Harry Potter       Gryffindor        88.0       90.0
# Lisa Turpin         Ravenclaw        86.5       84.0
# Michael Corner      Ravenclaw        85.5       86.5
# Draco Malfoy        Slytherin        84.5       81.0
# Susan Bones        Hufflepuff        84.0       83.5
# Ron Weasley        Gryffindor        83.0       87.5
# Hannah Abbott      Hufflepuff        80.5       84.5
# Ernie Macmillan    Hufflepuff        77.5       85.0
# Gregory Goyle       Slytherin        66.5       59.5
# Vincent Crabbe      Slytherin        64.0       60.0

# %%
df.loc["Hermione Granger"]
# Out:
# House         Gryffindor
# Potion_Ave         100.0
# Charm_Ave          100.0
# Name: Hermione Granger, dtype: object

# %% [markdown]
# #### reset_index() method
# * resets the index
# * promotes the current index into a column
# * creates a default numbered index

# %%
df = df.reset_index()

# %%
df
# Out:
#               Student       House  Potion_Ave  Charm_Ave
# 0    Hermione Granger  Gryffindor       100.0      100.0
# 1   Anthony Goldstein   Ravenclaw        89.0       87.0
# 2        Harry Potter  Gryffindor        88.0       90.0
# 3         Lisa Turpin   Ravenclaw        86.5       84.0
# 4      Michael Corner   Ravenclaw        85.5       86.5
# 5        Draco Malfoy   Slytherin        84.5       81.0
# 6         Susan Bones  Hufflepuff        84.0       83.5
# 7         Ron Weasley  Gryffindor        83.0       87.5
# 8       Hannah Abbott  Hufflepuff        80.5       84.5
# 9     Ernie Macmillan  Hufflepuff        77.5       85.0
# 10      Gregory Goyle   Slytherin        66.5       59.5
# 11     Vincent Crabbe   Slytherin        64.0       60.0

# %%
#set multiple indices
df = df.set_index(["House", "Student"])

# %%
df
# Out:
#                               Potion_Ave  Charm_Ave
# House      Student
# Gryffindor Hermione Granger        100.0      100.0
# Ravenclaw  Anthony Goldstein        89.0       87.0
# Gryffindor Harry Potter             88.0       90.0
# Ravenclaw  Lisa Turpin              86.5       84.0
#            Michael Corner           85.5       86.5
# Slytherin  Draco Malfoy             84.5       81.0
# Hufflepuff Susan Bones              84.0       83.5
# Gryffindor Ron Weasley              83.0       87.5
# Hufflepuff Hannah Abbott            80.5       84.5
#            Ernie Macmillan          77.5       85.0
# Slytherin  Gregory Goyle            66.5       59.5
#            Vincent Crabbe           64.0       60.0

# %%
df = df.sort_index()

# %%
df
# Out:
#                               Potion_Ave  Charm_Ave
# House      Student
# Gryffindor Harry Potter             88.0       90.0
#            Hermione Granger        100.0      100.0
#            Ron Weasley              83.0       87.5
# Hufflepuff Ernie Macmillan          77.5       85.0
#            Hannah Abbott            80.5       84.5
#            Susan Bones              84.0       83.5
# Ravenclaw  Anthony Goldstein        89.0       87.0
#            Lisa Turpin              86.5       84.0
#            Michael Corner           85.5       86.5
# Slytherin  Draco Malfoy             84.5       81.0
#            Gregory Goyle            66.5       59.5
#            Vincent Crabbe           64.0       60.0

# %% [markdown]
# * Multilevel indices are stored as a list of tuples:

# %%
df.index
# Out:
# MultiIndex([('Gryffindor',      'Harry Potter'),
#             ('Gryffindor',  'Hermione Granger'),
#             ('Gryffindor',       'Ron Weasley'),
#             ('Hufflepuff',   'Ernie Macmillan'),
#             ('Hufflepuff',     'Hannah Abbott'),
#             ('Hufflepuff',       'Susan Bones'),
#             ( 'Ravenclaw', 'Anthony Goldstein'),
#             ( 'Ravenclaw',       'Lisa Turpin'),
#             ( 'Ravenclaw',    'Michael Corner'),
#             ( 'Slytherin',      'Draco Malfoy'),
#             ( 'Slytherin',     'Gregory Goyle'),
#             ( 'Slytherin',    'Vincent Crabbe')],
#            names=['House', 'Student'])

# %%
df.index.values
# Out:
# array([('Gryffindor', 'Harry Potter'), ('Gryffindor', 'Hermione Granger'),
#        ('Gryffindor', 'Ron Weasley'), ('Hufflepuff', 'Ernie Macmillan'),
#        ('Hufflepuff', 'Hannah Abbott'), ('Hufflepuff', 'Susan Bones'),
#        ('Ravenclaw', 'Anthony Goldstein'), ('Ravenclaw', 'Lisa Turpin'),
#        ('Ravenclaw', 'Michael Corner'), ('Slytherin', 'Draco Malfoy'),
#        ('Slytherin', 'Gregory Goyle'), ('Slytherin', 'Vincent Crabbe')],
#       dtype=object)

# %% [markdown]
# ### 1.1. Selecting Rows from a Hierarchically-Indexed DataFrame

# %%
df.loc["Gryffindor"]
# Out:
#                   Potion_Ave  Charm_Ave
# Student
# Harry Potter            88.0       90.0
# Hermione Granger       100.0      100.0
# Ron Weasley             83.0       87.5

# %%
df.loc["Gryffindor", "Harry Potter"]
# Out:
# Potion_Ave    88.0
# Charm_Ave     90.0
# Name: (Gryffindor, Harry Potter), dtype: float64

# %%
df.loc["Gryffindor"].describe()
# Out:
#        Potion_Ave   Charm_Ave
# count    3.000000    3.000000
# mean    90.333333   92.500000
# std      8.736895    6.614378
# min     83.000000   87.500000
# 25%     85.500000   88.750000
# 50%     88.000000   90.000000
# 75%     94.000000   95.000000
# max    100.000000  100.000000

# %%
df.loc["Slytherin"].mean()
# Out:
# Potion_Ave    71.666667
# Charm_Ave     66.833333
# dtype: float64

# %% [markdown]
# #### How would you modify the code snippet above to retrieve the mean score for Slytherin on Potion_Ave?

# %%
#TODO in video
df.loc["Gryffindor"]["Potion_Ave"].mean()
# Out:
# 90.33333333333333

# %% [markdown]
# ### 1.2. Selecting Multiple Rows
# * When selecting multiple rows, provide a list of tuples corresponding to each row
#     * e.g., if selecting two rows, provide a list of two tuples
#         * Let's select Harry Potter and Draco Malfoy

# %%
df.loc[[("Gryffindor", "Harry Potter"), ("Slytherin", "Draco Malfoy")]]
# Out:
#                          Potion_Ave  Charm_Ave
# House      Student
# Gryffindor Harry Potter        88.0       90.0
# Slytherin  Draco Malfoy        84.5       81.0

# %% [markdown]
# ### 1.3. Selecting Multiple Rows with Specific Columns
# * Specify the list of columns as a second argument to **.loc[rows, columns]**

# %%
df.loc[[("Gryffindor", "Harry Potter"), ("Slytherin", "Draco Malfoy")], ["Potion_Ave"]]
# Out:
#                          Potion_Ave
# House      Student
# Gryffindor Harry Potter        88.0
# Slytherin  Draco Malfoy        84.5

# %% [markdown]
# ## 2. Working with Missing Values in DataFrames
# * Real-life datasets often contain missing values
# * Need to do something about those missing values before analyzing the data

# %%
dada = pd.read_csv("res/DADA.csv")

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 12                NaN           NaN      NaN      NaN    NaN
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 12                 NaN               NaN

# %% [markdown]
# ### Pandas and Missing Data
# * Pandas automatically assigns **NaN**, "Not a Number", to missing values while reading a file
# * By defaulty, empty cells are considered missing values, and hence, assigned NaN
# * Can specify the missing value used to indicate missing data
#     * use **na_values** keyword argument

# %%
pd.read_csv("res/DADA_NA.csv")
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter           100      100      100    100
# 1    Hermione Granger           100      100      100    100
# 2         Ron Weasley           100      100       95     95
# 3       Hannah Abbott            87       78       82     90
# 4         Susan Bones            77       84       75     87
# 5     Ernie Macmillan            81       81       76     81
# 6      Michael Corner            83       82       79     87
# 7   Anthony Goldstein            89       85       80     75
# 8         Lisa Turpin            80       77       83     86
# 9        Drace Malfoy            87       82       91     86
# 10      Gregory Goyle            65       60      -99     72
# 11     Vincent Crabbe            60      -99      -99     68
#
#     Petrificus Totalus  Expecto Patronum
# 0                  100               100
# 1                  100                95
# 2                   95                98
# 3                   85               -99
# 4                   81                75
# 5                   89               -99
# 6                   84               -99
# 7                   83               -99
# 8                   82                70
# 9                   83               -99
# 10                 -99               -99
# 11                  64               -99

# %%
pd.read_csv("res/DADA_NA.csv", na_values = "-99")
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter           100    100.0    100.0    100
# 1    Hermione Granger           100    100.0    100.0    100
# 2         Ron Weasley           100    100.0     95.0     95
# 3       Hannah Abbott            87     78.0     82.0     90
# 4         Susan Bones            77     84.0     75.0     87
# 5     Ernie Macmillan            81     81.0     76.0     81
# 6      Michael Corner            83     82.0     79.0     87
# 7   Anthony Goldstein            89     85.0     80.0     75
# 8         Lisa Turpin            80     77.0     83.0     86
# 9        Drace Malfoy            87     82.0     91.0     86
# 10      Gregory Goyle            65     60.0      NaN     72
# 11     Vincent Crabbe            60      NaN      NaN     68
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN

# %% [markdown]
# ### What to do with missing data?
# * Filter out missing data
# * Fill in missing data
# * Ignore missing data

# %% [markdown]
# ### 2.1. Filtering Out Missing Data
# * The dropna() method allows you to drop rows and columns with missing data
# * By default, dropna() drops any row containing a missing value

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 12                NaN           NaN      NaN      NaN    NaN
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 12                 NaN               NaN

# %%
dada_clean = dada.dropna()

# %%
dada_clean
# Out:
#             Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0      Harry Potter         100.0    100.0    100.0  100.0
# 1  Hermione Granger         100.0    100.0    100.0  100.0
# 2       Ron Weasley         100.0    100.0     95.0   95.0
# 4       Susan Bones          77.0     84.0     75.0   87.0
# 8       Lisa Turpin          80.0     77.0     83.0   86.0
#
#    Petrificus Totalus  Expecto Patronum
# 0               100.0             100.0
# 1               100.0              95.0
# 2                95.0              98.0
# 4                81.0              75.0
# 8                82.0              70.0

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 12                NaN           NaN      NaN      NaN    NaN
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 12                 NaN               NaN

# %% [markdown]
# ### 2.1.1. Filtering out empty rows
# It appears that Row 12 is in the dataset by mistake.

# %% [markdown]
# **dropna(how = "all")** will only drop rows that are all NaN.
# * If you want to drop columns in the same way, pass **axis=1**: **df.dropna(how="all", axis=1)**

# %%
dada= dada.dropna(how="all")

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN

# %% [markdown]
# * Alternatively, set skip_blank_lines=True when loading the dataset

# %%
pd.read_csv("res/DADA_NA.csv", skip_blank_lines=True)
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter           100      100      100    100
# 1    Hermione Granger           100      100      100    100
# 2         Ron Weasley           100      100       95     95
# 3       Hannah Abbott            87       78       82     90
# 4         Susan Bones            77       84       75     87
# 5     Ernie Macmillan            81       81       76     81
# 6      Michael Corner            83       82       79     87
# 7   Anthony Goldstein            89       85       80     75
# 8         Lisa Turpin            80       77       83     86
# 9        Drace Malfoy            87       82       91     86
# 10      Gregory Goyle            65       60      -99     72
# 11     Vincent Crabbe            60      -99      -99     68
#
#     Petrificus Totalus  Expecto Patronum
# 0                  100               100
# 1                  100                95
# 2                   95                98
# 3                   85               -99
# 4                   81                75
# 5                   89               -99
# 6                   84               -99
# 7                   83               -99
# 8                   82                70
# 9                   83               -99
# 10                 -99               -99
# 11                  64               -99

# %% [markdown]
# ### 2.2. Filling In Missing Data
# * Instead of filtering out missing data, you can fill in missing data with some other values.
# * the **fillna()** method allows you to fill in missing data with specific values

# %%
dada.fillna(0)
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      0.0   72.0
# 11     Vincent Crabbe          60.0      0.0      0.0   68.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               0.0
# 4                 81.0              75.0
# 5                 89.0               0.0
# 6                 84.0               0.0
# 7                 83.0               0.0
# 8                 82.0              70.0
# 9                 83.0               0.0
# 10                 0.0               0.0
# 11                64.0               0.0

# %% [markdown]
# ### Caution
# * fillna returns a new DF
# * If you want to update the original DF, set inplace=True
# > ```python
# dada.fillna(0, inplace = True)
# ```

# %% [markdown]
# ### 2.2.1. Filling In a Different Value for Each Column
# * Can fill in each column with a different value
# * Pass in a dictionary containing column names as keys and desired NA values as values
#     * **fillna(dictionary_of_values)**

# %%
default_col_values = {"Expelliarmus": 0, "Stupefy": 0, "Protego": 0, 
                      "Accio": 0, "Petrificus Totalus": 0, "Expecto Patronum": ""}

# %%
dada.fillna(default_col_values)
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      0.0   72.0
# 11     Vincent Crabbe          60.0      0.0      0.0   68.0
#
#     Petrificus Totalus Expecto Patronum
# 0                100.0            100.0
# 1                100.0             95.0
# 2                 95.0             98.0
# 3                 85.0
# 4                 81.0             75.0
# 5                 89.0
# 6                 84.0
# 7                 83.0
# 8                 82.0             70.0
# 9                 83.0
# 10                 0.0
# 11                64.0

# %% [markdown]
# <a id="3"></a>

# %% [markdown]
# ## 3. Working with Duplicates
# * Sometimes datasets contain duplicates record, which you may want to discard

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN

# %%
dada = dada.append(dada.iloc[0])

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 0        Harry Potter         100.0    100.0    100.0  100.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 0                100.0             100.0

# %% [markdown]
# ### 3.1. duplicated() method
# Returns a boolean Series indicating whether each row is a duplicated (whether it has been observed in a previous row)

# %%
dada.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 0      True
# dtype: bool

# %% [markdown]
# ### 3.2. drop_duplicates() method
# * Returns a DataFrame where the duplicates have been dropped

# %%
dada.drop_duplicates()
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN

# %% [markdown]
# * You can also specify a subset of columns to detect duplicates.
# * Pass in a list of column names as an argument to the **drop_duplicates()** method call.

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 0        Harry Potter         100.0    100.0    100.0  100.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 0                100.0             100.0

# %%
dada.drop_duplicates(["Student"])
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN

# %% [markdown]
# * By default, both duplicated() and drop_duplicates() keep the first observed value combination.
# * If you want to keep the last value, pass in **keep="last"**

# %%
dada
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter         100.0    100.0    100.0  100.0
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 0        Harry Potter         100.0    100.0    100.0  100.0
#
#     Petrificus Totalus  Expecto Patronum
# 0                100.0             100.0
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 0                100.0             100.0

# %%
dada.drop_duplicates(["Student"], keep="last")
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 1    Hermione Granger         100.0    100.0    100.0  100.0
# 2         Ron Weasley         100.0    100.0     95.0   95.0
# 3       Hannah Abbott          87.0     78.0     82.0   90.0
# 4         Susan Bones          77.0     84.0     75.0   87.0
# 5     Ernie Macmillan          81.0     81.0     76.0   81.0
# 6      Michael Corner          83.0     82.0     79.0   87.0
# 7   Anthony Goldstein          89.0     85.0     80.0   75.0
# 8         Lisa Turpin          80.0     77.0     83.0   86.0
# 9        Draco Malfoy          87.0     82.0     91.0   86.0
# 10      Gregory Goyle          65.0     60.0      NaN   72.0
# 11     Vincent Crabbe          60.0      NaN      NaN   68.0
# 0        Harry Potter         100.0    100.0    100.0  100.0
#
#     Petrificus Totalus  Expecto Patronum
# 1                100.0              95.0
# 2                 95.0              98.0
# 3                 85.0               NaN
# 4                 81.0              75.0
# 5                 89.0               NaN
# 6                 84.0               NaN
# 7                 83.0               NaN
# 8                 82.0              70.0
# 9                 83.0               NaN
# 10                 NaN               NaN
# 11                64.0               NaN
# 0                100.0             100.0

# %% [markdown]
# <a id="4"></a>

# %% [markdown]
# ## 4. Replacing Values
# * Beyond filtering or fill in missing data, we can replace certain values with new values.
# * **df.replace(current_value, new_value)**

# %%
dada_NA = pd.read_csv("res/DADA_NA.csv")

# %%
dada_NA
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter           100      100      100    100
# 1    Hermione Granger           100      100      100    100
# 2         Ron Weasley           100      100       95     95
# 3       Hannah Abbott            87       78       82     90
# 4         Susan Bones            77       84       75     87
# 5     Ernie Macmillan            81       81       76     81
# 6      Michael Corner            83       82       79     87
# 7   Anthony Goldstein            89       85       80     75
# 8         Lisa Turpin            80       77       83     86
# 9        Drace Malfoy            87       82       91     86
# 10      Gregory Goyle            65       60      -99     72
# 11     Vincent Crabbe            60      -99      -99     68
#
#     Petrificus Totalus  Expecto Patronum
# 0                  100               100
# 1                  100                95
# 2                   95                98
# 3                   85               -99
# 4                   81                75
# 5                   89               -99
# 6                   84               -99
# 7                   83               -99
# 8                   82                70
# 9                   83               -99
# 10                 -99               -99
# 11                  64               -99

# %%
dada_NA.replace(-99, "NaN") #numpy has a specific attribute for NaN: np.nan
# Out:
#               Student  Expelliarmus Stupefy Protego  Accio Petrificus Totalus  \
# 0        Harry Potter           100     100     100    100                100
# 1    Hermione Granger           100     100     100    100                100
# 2         Ron Weasley           100     100      95     95                 95
# 3       Hannah Abbott            87      78      82     90                 85
# 4         Susan Bones            77      84      75     87                 81
# 5     Ernie Macmillan            81      81      76     81                 89
# 6      Michael Corner            83      82      79     87                 84
# 7   Anthony Goldstein            89      85      80     75                 83
# 8         Lisa Turpin            80      77      83     86                 82
# 9        Drace Malfoy            87      82      91     86                 83
# 10      Gregory Goyle            65      60     NaN     72                NaN
# 11     Vincent Crabbe            60     NaN     NaN     68                 64
#
#    Expecto Patronum
# 0               100
# 1                95
# 2                98
# 3               NaN
# 4                75
# 5               NaN
# 6               NaN
# 7               NaN
# 8                70
# 9               NaN
# 10              NaN
# 11              NaN

# %%
dada_NA
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter           100      100      100    100
# 1    Hermione Granger           100      100      100    100
# 2         Ron Weasley           100      100       95     95
# 3       Hannah Abbott            87       78       82     90
# 4         Susan Bones            77       84       75     87
# 5     Ernie Macmillan            81       81       76     81
# 6      Michael Corner            83       82       79     87
# 7   Anthony Goldstein            89       85       80     75
# 8         Lisa Turpin            80       77       83     86
# 9        Drace Malfoy            87       82       91     86
# 10      Gregory Goyle            65       60      -99     72
# 11     Vincent Crabbe            60      -99      -99     68
#
#     Petrificus Totalus  Expecto Patronum
# 0                  100               100
# 1                  100                95
# 2                   95                98
# 3                   85               -99
# 4                   81                75
# 5                   89               -99
# 6                   84               -99
# 7                   83               -99
# 8                   82                70
# 9                   83               -99
# 10                 -99               -99
# 11                  64               -99

# %%
dada_NA.replace("Drace Malfoy", "Draco Malfoy", inplace=True)

# %%
dada_NA
# Out:
#               Student  Expelliarmus  Stupefy  Protego  Accio  \
# 0        Harry Potter           100      100      100    100
# 1    Hermione Granger           100      100      100    100
# 2         Ron Weasley           100      100       95     95
# 3       Hannah Abbott            87       78       82     90
# 4         Susan Bones            77       84       75     87
# 5     Ernie Macmillan            81       81       76     81
# 6      Michael Corner            83       82       79     87
# 7   Anthony Goldstein            89       85       80     75
# 8         Lisa Turpin            80       77       83     86
# 9        Draco Malfoy            87       82       91     86
# 10      Gregory Goyle            65       60      -99     72
# 11     Vincent Crabbe            60      -99      -99     68
#
#     Petrificus Totalus  Expecto Patronum
# 0                  100               100
# 1                  100                95
# 2                   95                98
# 3                   85               -99
# 4                   81                75
# 5                   89               -99
# 6                   84               -99
# 7                   83               -99
# 8                   82                70
# 9                   83               -99
# 10                 -99               -99
# 11                  64               -99

# %% [markdown]
# * If you want to replace multiple values at once, pass a list and then the substitute value(s)
#
# ```python
# dada_NA.replace([-99, -999], "NaN")
# dada_NA.replace([-99, -999], ["NaN", 0])
# dada_NA.replace({-99: "NaN", -999: 0})
# ```

# %% [markdown]
# <a id="5"></a>

# %% [markdown]
# ## 5. Renaming Axis Indices
# * Can rename rows and columns using the **rename()** method
# * Use *column* and *index* keywords arguments
# * Pass **inplace=True** if you want to modify the original df

# %%
dada_NA = dada_NA.set_index("Student")

# %%
dada_NA
# Out:
#                    Expelliarmus  Stupefy  Protego  Accio  Petrificus Totalus  \
# Student
# Harry Potter                100      100      100    100                 100
# Hermione Granger            100      100      100    100                 100
# Ron Weasley                 100      100       95     95                  95
# Hannah Abbott                87       78       82     90                  85
# Susan Bones                  77       84       75     87                  81
# Ernie Macmillan              81       81       76     81                  89
# Michael Corner               83       82       79     87                  84
# Anthony Goldstein            89       85       80     75                  83
# Lisa Turpin                  80       77       83     86                  82
# Draco Malfoy                 87       82       91     86                  83
# Gregory Goyle                65       60      -99     72                 -99
# Vincent Crabbe               60      -99      -99     68                  64
#
#                    Expecto Patronum
# Student
# Harry Potter                    100
# Hermione Granger                 95
# Ron Weasley                      98
# Hannah Abbott                   -99
# Susan Bones                      75
# Ernie Macmillan                 -99
# Michael Corner                  -99
# Anthony Goldstein               -99
# Lisa Turpin                      70
# Draco Malfoy                    -99
# Gregory Goyle                   -99
# Vincent Crabbe                  -99

# %%
dada_NA = dada_NA.rename(index={"Harry Potter": "Harry", "Hermione Granger": "Hermione", "Ron Weasley": "Ron"})

# %%
dada_NA
# Out:
#                    Expelliarmus  Stupefy  Protego  Accio  Petrificus Totalus  \
# Student
# Harry                       100      100      100    100                 100
# Hermione                    100      100      100    100                 100
# Ron                         100      100       95     95                  95
# Hannah Abbott                87       78       82     90                  85
# Susan Bones                  77       84       75     87                  81
# Ernie Macmillan              81       81       76     81                  89
# Michael Corner               83       82       79     87                  84
# Anthony Goldstein            89       85       80     75                  83
# Lisa Turpin                  80       77       83     86                  82
# Draco Malfoy                 87       82       91     86                  83
# Gregory Goyle                65       60      -99     72                 -99
# Vincent Crabbe               60      -99      -99     68                  64
#
#                    Expecto Patronum
# Student
# Harry                           100
# Hermione                         95
# Ron                              98
# Hannah Abbott                   -99
# Susan Bones                      75
# Ernie Macmillan                 -99
# Michael Corner                  -99
# Anthony Goldstein               -99
# Lisa Turpin                      70
# Draco Malfoy                    -99
# Gregory Goyle                   -99
# Vincent Crabbe                  -99
